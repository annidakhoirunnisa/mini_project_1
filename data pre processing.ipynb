# %%
# importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Data and Describe

# %%
# load the dataset
df = pd.read_csv('employee_retention.csv')
# show data samples
df.sample(5)
# Out:
#             Username  EnterpriseID StatusPernikahan JenisKelamin  \
# 253     mildChowder7        111643    Belum_menikah       Wanita
# 56      grizzledCod7        111184    Belum_menikah       Wanita
# 128   brainyGranola0        111427    Belum_menikah         Pria
# 280     anxiousTeal2        111378    Belum_menikah       Wanita
# 53   selfishBasmati2        110407          Lainnya       Wanita
#
#     StatusKepegawaian                     Pekerjaan           JenjangKarir  \
# 253          FullTime  Software Engineer (Back End)              Mid_level
# 56          Outsource               Product Manager              Mid_level
# 128         Outsource   Software Engineer (Android)              Mid_level
# 280          FullTime  Software Engineer (Back End)              Mid_level
# 53           FullTime      Product Design (UI & UX)  Freshgraduate_program
#
#     PerformancePegawai       AsalDaerah      HiringPlatform  ...  \
# 253      Sangat_kurang    Jakarta Pusat              Indeed  ...
# 56        Sangat_bagus    Jakarta Barat              Indeed  ...
# 128              Biasa  Jakarta Selatan       CareerBuilder  ...
# 280              Bagus    Jakarta Timur   Employee_Referral  ...
# 53               Biasa    Jakarta Timur  Diversity_Job_Fair  ...
#
#             NomorHP                           Email  TingkatPendidikan  \
# 253  +6285951035xxx       mildChowder7653@yahoo.com            Sarjana
# 56   +6281209062xxx     grizzledCod7824@hotmail.com             Doktor
# 128  +6281268533xxx     brainyGranola0883@gmail.com             Doktor
# 280  +6289567915xxx       anxiousTeal2015@gmail.com            Sarjana
# 53   +6285718122xxx  selfishBasmati2000@hotmail.com           Magister
#
#      PernahBekerja  IkutProgramLOP   AlasanResign TanggalLahir TanggalHiring  \
# 253              1             NaN      jam_kerja   1968-08-15     2012-5-14
# 56               1             NaN  masih_bekerja   1977-11-22     2011-5-31
# 128              1             NaN  masih_bekerja   1954-10-12    2014-05-12
# 280              1             NaN            NaN   1984-09-16    2014-11-10
# 53               1             NaN  tidak_bahagia   1987-04-04     2015-2-16
#
#     TanggalPenilaianKaryawan  TanggalResign
# 253                2020-1-31     2017-11-15
# 56                2020-01-10              -
# 128                2020-1-28              -
# 280               2020-01-04              -
# 53                 2020-2-18      2018-9-23
#
# [5 rows x 25 columns]

# %%
# check the data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 25 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Username                            287 non-null    object
#  1   EnterpriseID                        287 non-null    int64
#  2   StatusPernikahan                    287 non-null    object
#  3   JenisKelamin                        287 non-null    object
#  4   StatusKepegawaian                   287 non-null    object
#  5   Pekerjaan                           287 non-null    object
#  6   JenjangKarir                        287 non-null    object
#  7   PerformancePegawai                  287 non-null    object
#  8   AsalDaerah                          287 non-null    object
#  9   HiringPlatform                      287 non-null    object
#  10  SkorSurveyEngagement                287 non-null    int64
#  11  SkorKepuasanPegawai                 282 non-null    float64
#  12  JumlahKeikutsertaanProjek           284 non-null    float64
#  13  JumlahKeterlambatanSebulanTerakhir  286 non-null    float64
#  14  JumlahKetidakhadiran                281 non-null    float64
#  15  NomorHP                             287 non-null    object
#  16  Email                               287 non-null    object
#  17  TingkatPendidikan                   287 non-null    object
#  18  PernahBekerja                       287 non-null    object
#  19  IkutProgramLOP                      29 non-null     float64
#  20  AlasanResign                        221 non-null    object
#  21  TanggalLahir                        287 non-null    object
#  22  TanggalHiring                       287 non-null    object
#  23  TanggalPenilaianKaryawan            287 non-null    object
#  24  TanggalResign                       287 non-null    object
# dtypes: float64(5), int64(2), object(18)
# memory usage: 56.2+ KB

# %%
df.nunique()
# Out:
# Username                              285
# EnterpriseID                          287
# StatusPernikahan                        5
# JenisKelamin                            2
# StatusKepegawaian                       3
# Pekerjaan                              14
# JenjangKarir                            3
# PerformancePegawai                      5
# AsalDaerah                              5
# HiringPlatform                          9
# SkorSurveyEngagement                    5
# SkorKepuasanPegawai                     5
# JumlahKeikutsertaanProjek               9
# JumlahKeterlambatanSebulanTerakhir      7
# JumlahKetidakhadiran                   22
# NomorHP                               287
# Email                                 287
# TingkatPendidikan                       3
# PernahBekerja                           2
# IkutProgramLOP                          2
# AlasanResign                           11
# TanggalLahir                          284
# TanggalHiring                          97
# TanggalPenilaianKaryawan              127
# TanggalResign                          53
# dtype: int64

# %%
# Describe numerical features
df.describe()
# Out:
#         EnterpriseID  SkorSurveyEngagement  SkorKepuasanPegawai  \
# count     287.000000            287.000000           282.000000
# mean   105923.324042              3.101045             3.904255
# std      4044.977599              0.836388             0.913355
# min    100282.000000              1.000000             1.000000
# 25%    101269.000000              3.000000             3.000000
# 50%    106069.000000              3.000000             4.000000
# 75%    110514.500000              4.000000             5.000000
# max    111703.000000              5.000000             5.000000
#
#        JumlahKeikutsertaanProjek  JumlahKeterlambatanSebulanTerakhir  \
# count                 284.000000                          286.000000
# mean                    1.179577                            0.412587
# std                     2.294441                            1.275016
# min                     0.000000                            0.000000
# 25%                     0.000000                            0.000000
# 50%                     0.000000                            0.000000
# 75%                     0.000000                            0.000000
# max                     8.000000                            6.000000
#
#        JumlahKetidakhadiran  IkutProgramLOP
# count            281.000000       29.000000
# mean              10.448399        0.517241
# std                6.902252        0.508548
# min                1.000000        0.000000
# 25%                5.000000        0.000000
# 50%               10.000000        1.000000
# 75%               15.000000        1.000000
# max               55.000000        1.000000

# %%
# Convert columns to categorical data type
cats_col = [
    'StatusPernikahan', 'JenisKelamin', 'StatusKepegawaian', 'Pekerjaan',
    'JenjangKarir', 'PerformancePegawai', 'AsalDaerah', 'HiringPlatform',
    'SkorSurveyEngagement', 'SkorKepuasanPegawai', 'TingkatPendidikan',
    'PernahBekerja', 'IkutProgramLOP', 'AlasanResign'
]

for column in cats_col:
    df[column] = df[column].astype('category')

# %%
# Describe categorical features
df[cats_col].describe()
# Out:
#        StatusPernikahan JenisKelamin StatusKepegawaian  \
# count               287          287               287
# unique                5            2                 3
# top       Belum_menikah       Wanita          FullTime
# freq                132          167               217
#
#                            Pekerjaan           JenjangKarir  \
# count                            287                    287
# unique                            14                      3
# top     Software Engineer (Back End)  Freshgraduate_program
# freq                             109                    169
#
#        PerformancePegawai     AsalDaerah HiringPlatform  SkorSurveyEngagement  \
# count                 287            287            287                   287
# unique                  5              5              9                     5
# top                 Biasa  Jakarta Pusat         Indeed                     3
# freq                   85             72             85                   132
#
#         SkorKepuasanPegawai TingkatPendidikan PernahBekerja  IkutProgramLOP  \
# count                 282.0               287           287            29.0
# unique                  5.0                 3             2             2.0
# top                     3.0           Sarjana             1             1.0
# freq                   96.0               176           286            15.0
#
#          AlasanResign
# count             221
# unique             11
# top     masih_bekerja
# freq              132

# %%
# Check values of categorical features
for column in cats_col:
    print(df[column].value_counts())
# Out:
# StatusPernikahan
# Belum_menikah    132
# Menikah           57
# Lainnya           48
# Bercerai          47
# -                  3
# Name: count, dtype: int64
# JenisKelamin
# Wanita    167
# Pria      120
# Name: count, dtype: int64
# StatusKepegawaian
# FullTime      217
# Outsource      66
# Internship      4
# Name: count, dtype: int64
# Pekerjaan
# Software Engineer (Back End)      109
# Software Engineer (Front End)      72
# Product Design (UI & UX)           24
# Software Engineer (Android)        24
# Product Manager                    17
# Data Analyst                       16
# Data Engineer                      10
# DevOps Engineer                     3
# Scrum Master                        3
# Software Engineer (iOS)             3
# Digital Product Manager             2
# Machine Learning Engineer           2
# Product Design (UX Researcher)      1
# Software Architect                  1
# Name: count, dtype: int64
# JenjangKarir
# Freshgraduate_program    169
# Mid_level                 70
# Senior_level              48
# Name: count, dtype: int64
# PerformancePegawai
# Biasa            85
# Bagus            74
# Sangat_bagus     73
# Kurang           31
# Sangat_kurang    24
# Name: count, dtype: int64
# AsalDaerah
# Jakarta Pusat      72
# Jakarta Timur      63
# Jakarta Barat      55
# Jakarta Utara      52
# Jakarta Selatan    45
# Name: count, dtype: int64
# HiringPlatform
# Indeed                     85
# LinkedIn                   69
# Google_Search              46
# Diversity_Job_Fair         27
# Employee_Referral          24
# CareerBuilder              22
# Website                    11
# Other                       2
# On-line_Web_application     1
# Name: count, dtype: int64
# SkorSurveyEngagement
# 3    132
# 4     96
# 2     43
# 1     14
# 5      2
# Name: count, dtype: int64
# SkorKepuasanPegawai
# 3.0    96
# 5.0    91
# 4.0    85
# 2.0     8
# 1.0     2
# Name: count, dtype: int64
# TingkatPendidikan
# Sarjana     176
# Magister     87
# Doktor       24
# Name: count, dtype: int64
# PernahBekerja
# 1      286
# yes      1
# Name: count, dtype: int64
# IkutProgramLOP
# 1.0    15
# 0.0    14
# Name: count, dtype: int64
# AlasanResign
# masih_bekerja               132
# jam_kerja                    16
# ganti_karir                  14
# kejelasan_karir              11
# tidak_bisa_remote            11
# toxic_culture                10
# leadership                    9
# tidak_bahagia                 8
# Product Design (UI & UX)      4
# internal_conflict             4
# apresiasi                     2
# Name: count, dtype: int64

# %% [markdown]
# ### Overview: The value 'yes' in 'PernahBekerja' column seems to be a mistake. Assuming that '1' represents 'yes' and '0' represents 'no,' the value 'yes' should be replaced with '1'.

# %% [markdown]
# # Data Pre Processing

# %%
# Create a copy of the dataset to preserve the original data
df_cleaned = df.copy()

# %%
# Check duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Check null values
df.isna().sum()
# Out:
# Username                                0
# EnterpriseID                            0
# StatusPernikahan                        0
# JenisKelamin                            0
# StatusKepegawaian                       0
# Pekerjaan                               0
# JenjangKarir                            0
# PerformancePegawai                      0
# AsalDaerah                              0
# HiringPlatform                          0
# SkorSurveyEngagement                    0
# SkorKepuasanPegawai                     5
# JumlahKeikutsertaanProjek               3
# JumlahKeterlambatanSebulanTerakhir      1
# JumlahKetidakhadiran                    6
# NomorHP                                 0
# Email                                   0
# TingkatPendidikan                       0
# PernahBekerja                           0
# IkutProgramLOP                        258
# AlasanResign                           66
# TanggalLahir                            0
# TanggalHiring                           0
# TanggalPenilaianKaryawan                0
# TanggalResign                           0
# dtype: int64

# %% [markdown]
# ### Overview:
# - Due to the fact that the columns 'JumlahKeikutsertaanProjek', 'JumlahKeterlambatanSebulanTerakhir', and 'JumlahKetidakhadiran' must contain integer values, nulls will be imputed using the median.
#
# - Column 'IkutProgramLOP' contains 89.8% null values, indicating it has limited utility for future analysis.
#
# - Null values in the column 'AlasanResign' and 'SkorKepuasanPegawai' will be imputed with the most frequently occurring value.

# %%
# Replace incorrect value in 'PernahBekerja'
df_cleaned['PernahBekerja'] = df_cleaned['PernahBekerja'].replace('yes', 1)

# %%
# Impute numerical columns with median
nums_to_impute = ['JumlahKeikutsertaanProjek', 'JumlahKeterlambatanSebulanTerakhir', 'JumlahKetidakhadiran']

for column in nums_to_impute:
    median = df[column].median()
    df_cleaned[column].fillna(median, inplace=True)

# %%
# Impute categorical features with most frequent value
cats_to_impute = ['AlasanResign', 'SkorKepuasanPegawai']

for column in cats_to_impute:
    mode = df[column].mode()[0]
    df_cleaned[column].fillna(mode, inplace=True)

# %%
# Drop 'PernahBekerja' column as it contains only a single value and 'IkutProgramLOP' column as it contains too many nulls.
df_cleaned.drop(columns=['PernahBekerja', 'IkutProgramLOP'], inplace=True)

# %%
# Check nulls and dropeed columns in df_cleaned
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 23 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Username                            287 non-null    object
#  1   EnterpriseID                        287 non-null    int64
#  2   StatusPernikahan                    287 non-null    category
#  3   JenisKelamin                        287 non-null    category
#  4   StatusKepegawaian                   287 non-null    category
#  5   Pekerjaan                           287 non-null    category
#  6   JenjangKarir                        287 non-null    category
#  7   PerformancePegawai                  287 non-null    category
#  8   AsalDaerah                          287 non-null    category
#  9   HiringPlatform                      287 non-null    category
#  10  SkorSurveyEngagement                287 non-null    category
#  11  SkorKepuasanPegawai                 287 non-null    category
#  12  JumlahKeikutsertaanProjek           287 non-null    float64
#  13  JumlahKeterlambatanSebulanTerakhir  287 non-null    float64
#  14  JumlahKetidakhadiran                287 non-null    float64
#  15  NomorHP                             287 non-null    object
#  16  Email                               287 non-null    object
#  17  TingkatPendidikan                   287 non-null    category
#  18  AlasanResign                        287 non-null    category
#  19  TanggalLahir                        287 non-null    object
#  20  TanggalHiring                       287 non-null    object
#  21  TanggalPenilaianKaryawan            287 non-null    object
#  22  TanggalResign                       287 non-null    object
# dtypes: category(12), float64(3), int64(1), object(7)
# memory usage: 31.1+ KB
